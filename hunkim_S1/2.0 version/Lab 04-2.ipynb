# %%
import tensorflow as tf
import numpy as np

xy = np.loadtxt('data-01-test-score.csv', delimiter=',', dtype=np.float32)
x_data = xy[:, 0:-1]
y_data = xy[:, [-1]]

print(x_data.shape, x_data, len(x_data))
print(y_data.shape, y_data)
# Out:
# (6, 3) [[ 73.  80.  75.]
#  [ 93.  88.  93.]
#  [ 89.  91.  90.]
#  [ 96.  98. 100.]
#  [ 73.  66.  70.]
#  [ 53.  46.  55.]] 6
# (6, 1) [[152.]
#  [185.]
#  [180.]
#  [196.]
#  [142.]
#  [101.]]

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(1, activation='linear', dtype='float32')
])

sgd = tf.optimizers.SGD(learning_rate=1e-5)
model.compile(optimizer=sgd, 
              loss='mean_squared_error',
              metrics=[])

model.fit(x_data, y_data, verbose=2, epochs=2001)
# Out:
# Train on 6 samples
# Epoch 1/2001
# 6/6 - 1s - loss: 103492.6562
# Epoch 2/2001
# 6/6 - 0s - loss: 38114.1367
# Epoch 3/2001
# 6/6 - 0s - loss: 14038.0967
# Epoch 4/2001
# 6/6 - 0s - loss: 5171.9478
# Epoch 5/2001
# 6/6 - 0s - loss: 1906.9355
# Epoch 6/2001
# 6/6 - 0s - loss: 704.5730
# Epoch 7/2001
# 6/6 - 0s - loss: 261.7957
# Epoch 8/2001
# 6/6 - 0s - loss: 98.7385
# Epoch 9/2001
# 6/6 - 0s - loss: 38.6909
# Epoch 10/2001
# 6/6 - 0s - loss: 16.5770
# Epoch 11/2001
# 6/6 - 0s - loss: 8.4324
# Epoch 12/2001
# 6/6 - 0s - loss: 5.4320
# Epoch 13/2001
# 6/6 - 0s - loss: 4.3260
# Epoch 14/2001
# 6/6 - 0s - loss: 3.9177
# Epoch 15/2001
# 6/6 - 0s - loss: 3.7663
# Epoch 16/2001
# 6/6 - 0s - loss: 3.7095
# Epoch 17/2001
# 6/6 - 0s - loss: 3.6876
# Epoch 18/2001
# 6/6 - 0s - loss: 3.6784
# Epoch 19/2001
# 6/6 - 0s - loss: 3.6740
# Epoch 20/2001
# 6/6 - 0s - loss: 3.6714
# Epoch 21/2001
# 6/6 - 0s - loss: 3.6694
# Epoch 22/2001
# 6/6 - 0s - loss: 3.6676
# Epoch 23/2001
# ...

# %%
print("Your score will be ", model.predict([[100, 70, 101]]))
print("Other scores will be ", model.predict([[60, 70, 110], [90, 100, 80]]))
# Out:
# Your score will be  [[186.75528]]
# Other scores will be  [[150.9692 ]
#  [180.47682]]
